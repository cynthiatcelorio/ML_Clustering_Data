# %%
import numpy as np
import pandas as pd

import cv2
import os
import matplotlib.pyplot as plt

# %%
# !git clone "https://github.com/cynthiatcelorio/ML_Clustering.git"
# Out:
# Cloning into 'ML_Clustering'...
# remote: Enumerating objects: 8156, done.
# remote: Total 8156 (delta 0), reused 0 (delta 0), pack-reused 8156
# Receiving objects: 100% (8156/8156), 149.87 MiB | 39.72 MiB/s, done.
# Checking out files: 100% (8154/8154), done.

# %%
ruta_train = "/content/ML_Clustering/train"
ruta_test = "/content/ML_Clustering/test"

train = []
img_size = 80

for img in os.listdir(ruta_train):
  img = cv2.imread(os.path.join(ruta_train, img))
  img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  img_gray_resize = cv2.resize(img_gray, (img_size, img_size))
  train.append([img_gray_resize])

print(len(train))
print()
# Out:
# 7889

# %%
plt.figure()
plt.imshow(np.squeeze(train[100]))
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# https://stackoverflow.com/questions/38351224/creating-a-pandas-dataframe-from-a-list-of-image-files
